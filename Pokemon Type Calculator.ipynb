# %%
import os
from colorama import Fore, Style

# %%
#Assign pokemon types to variables
n = "Normal"
f = "Fire"
w = "Water"
elec = "Electric"
g = "Grass"
i = "Ice"
fg = "Fighting"
p = "Poison"
grd = "Ground"
fly = "Flying"
psy = "Psychic"
bug = "Bug"
rck = "Rock"
gh = "Ghost"
drg = "Dragon"
drk = "Dark"
stl = "Steel"
fry = "Fairy"

# %%
#List of Pokemon types
print("Choose between the following Pokemon types only:")
print(n)
print(f)
print(w)
print(elec)
print(g)
print(i)
print(fg)
print(p)
print(grd)
print(fly)
print(psy)
print(bug)
print(rck)
print(gh)
print(drg)
print(drk)
print(stl)
print(fry)
print(" ")
#Input Pokemon type
pokemon_type = str(input(Style.BRIGHT + "Enter the pokemon type: " + Style.RESET_ALL))

#Check if invalid input
if not isinstance(pokemon_type, str):
    print("Invalid input.")
else:
    # Clear the terminal screen
    os.system('cls' if os.name == 'nt' else 'clear')

#Create if-else statements-------------------------------------------------------------------------------------

if (pokemon_type == "Normal"):
    print(Style.BRIGHT + "Normal is not very effective against:" + Style.RESET_ALL)
    print("-",rck)
    print("-",stl) 
    print("and has no effect on", gh)
#--------------------------------------------------------------------------------------------------------------   
elif (pokemon_type == "Fire"):
    print(Style.BRIGHT + "Fire is super effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",i)
    print("-",bug)
    print("-",stl)
    
    print(Style.BRIGHT + "Fire is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",w)
    print("-",rck)
    print("-",drg)
#---------------------------------------------------------------------------------------------------------------
elif (pokemon_type == "Water"):
    print(Style.BRIGHT + "Water is super effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",grd)
    print("-",rck)
    
    print(Style.BRIGHT + "Water is not very effective against:" + Style.RESET_ALL)
    print("-","-",w)
    print("-",g)
    print("-",drg)
#----------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Electric"):
    print(Style.BRIGHT + "Electric is super effective against:" + Style.RESET_ALL)
    print("-",w)
    print("-",fly)
    
    print(Style.BRIGHT + "Electric is not very effective against:" + Style.RESET_ALL)
    print("-",elec)
    print("-",g)
    print("-",drg)
    print("and has no effect on", grd)
#----------------------------------------------------------------------------------------------------------------  
elif (pokemon_type == "Grass"):
    print(Style.BRIGHT + "Grass is super effective against:" + Style.RESET_ALL)
    print("-",w)
    print("-",grd)
    print("-",rck)
    
    print(Style.BRIGHT + "Grass is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",g)
    print("-",p)
    print("-",fly)
    print("-",bug)
    print("-",drg)
    print("-",stl)
#-----------------------------------------------------------------------------------------------------------------   
elif (pokemon_type == "Ice"):
    print(Style.BRIGHT + "Ice is super effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",grd)
    print("-",fly)
    print("-",drg)
    
    print(Style.BRIGHT + "Ice is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",w)
    print("-",i)
    print("-",stl)
#------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Fighting"):
    print(Style.BRIGHT + "Fighting is super effective against:" + Style.RESET_ALL)
    print("-",n)
    print("-",i)
    print("-",rck)
    print("-",drk)
    print("-",stl)
    
    print(Style.BRIGHT + "Fighting is not very effective against:" + Style.RESET_ALL)
    print("-",p)
    print("-",fly)
    print("-",psy)
    print("-",bug)
    print("-",fry)
    print("and has no effect on", gh)
#-------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Poison"):
    print(Style.BRIGHT + "Poison is super effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",fry)
    
    print(Style.BRIGHT + "Poison is not very effective against:" + Style.RESET_ALL)
    print("-",p)
    print("-",grd)
    print("-",rck)
    print("-",gh)
    print("and has no effect on", stl)
#-------------------------------------------------------------------------------------------------------------------   
elif (pokemon_type == "Ground"):
    print(Style.BRIGHT + "Ground is super effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",elec)
    print("-",p)
    print("-",rck)
    print("-",stl)
    
    print(Style.BRIGHT + "Ground is not very effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",bug)
    print("and has no effect on", fly)
#-------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Flying"):
    print(Style.BRIGHT + "Flying is super effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",fg)
    print("-",bug)
    
    print(Style.BRIGHT + "Flying is not very effective against:" + Style.RESET_ALL)
    print("-",elec)
    print("-",rck)
    print("-",stl)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Psychic"):
    print(Style.BRIGHT + "Psychic is not very effective against:" + Style.RESET_ALL)
    print("-",fg)
    print("-",p)
    
    print(Style.BRIGHT + "Psychic is not very effective against:" + Style.RESET_ALL)
    print("-",psy)
    print("-",stl)
    print("and has no effect on", drk)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Bug"):
    print(Style.BRIGHT + "Bug is super effective against:" + Style.RESET_ALL)
    print("-",g)
    print("-",psy)
    print("-",drk)
    
    print(Style.BRIGHT + "Bug is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",fg)
    print("-",p)
    print("-",fly)
    print("-",gh)
    print("-",stl)
    print("-",fry)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Rock"):
    print(Style.BRIGHT + "Rock is super effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",i)
    print("-",fly)
    print("-",bug)
    
    print(Style.BRIGHT + "Rock is not very effective against:" + Style.RESET_ALL)
    print("-",fg)
    print("-",grd)
    print("-",stl)
#--------------------------------------------------------------------------------------------------------------------   
elif (pokemon_type == "Ghost"):
    print(Style.BRIGHT + "Ghost is super effective against:" + Style.RESET_ALL)
    print("-",psy)
    print("-",gh)
    
    print(Style.BRIGHT + "Ghost is not very effective against:" + Style.RESET_ALL)
    print("-",drk)
    print("and has no effect on", n)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Dragon"):
    print(Style.BRIGHT + "Dragon is super effective against:" + Style.RESET_ALL)
    print("-",drg)
    
    print(Style.BRIGHT + "Dragon is not very effective against:" + Style.RESET_ALL)
    print("-",stl)
    print("and has no effect on", fry)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Dark"):
    print(Style.BRIGHT + "Dark is super effective against:" + Style.RESET_ALL)
    print("-",psy)
    print("-",gh)
    
    print(Style.BRIGHT + "Dark is not very effective against:" + Style.RESET_ALL)
    print("-",fg)
    print("-",drk)
    print("-",fry)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Steel"):
    print(Style.BRIGHT + "Steel is super effective against:" + Style.RESET_ALL)
    print("-",i)
    print("-",rck)
    print("-",fry)
    
    print(Style.BRIGHT + "Steel is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",w)
    print("-",elec)
    print("-",stl)
#--------------------------------------------------------------------------------------------------------------------    
elif (pokemon_type == "Fairy"):
    print(Style.BRIGHT + "Fairy is super effective against:" + Style.RESET_ALL)
    print("-",fg)
    print("-",drg)
    print("-",drk)
    
    print(Style.BRIGHT + "Fairy is not very effective against:" + Style.RESET_ALL)
    print("-",f)
    print("-",p)
    print("-",stl)
#--------------------------------------------------------------------------------------------------------------------    
else:
    print("Invalid pokemon type.")
# Out:
# Choose between the following Pokemon types only:
# Normal
# Fire
# Water
# Electric
# Grass
# Ice
# Fighting
# Poison
# Ground
# Flying
# Psychic
# Bug
# Rock
# Ghost
# Dragon
# Dark
# Steel
# Fairy
#
# Enter the pokemon type: Dragon
# Dragon is super effective against:
# - Dragon
# Dragon is not very effective against:
# - Steel
# and has no effect on Fairy
